# %% [markdown]
# <a href="https://colab.research.google.com/github/nandinisingh7/Computer-Vision/blob/main/Nandini_Singh_CV7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nandini Singh
#
# 1032211677
#
# Division A1
#
# Batch A2

# %%
import cv2 as cv
from matplotlib import pyplot as plt

# Upload your image file 'mountain image.webp' to your Google Colab environment

# Install OpenCV (if not already installed)
# !pip install opencv-python-headless

# Read left and right images
imgL = cv.imread('/content/mountain image.webp', cv.IMREAD_GRAYSCALE)
imgR = cv.imread('/content/mountain image1.jpeg', cv.IMREAD_GRAYSCALE)

# Create StereoBM object
stereo = cv.StereoBM_create(numDisparities=64, blockSize=15)

# Compute disparity
disparity = stereo.compute(imgL, imgR)

# Convert disparity map to depth map (assuming baseline and focal length)
baseline = 1
focal_length = 1
depth_map = baseline * focal_length / disparity

# Plot subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot left image
axs[0, 0].imshow(imgL, cmap='gray')
axs[0, 0].set_title('Left Image')

# Plot right image
axs[0, 1].imshow(imgR, cmap='gray')
axs[0, 1].set_title('Right Image')

# Plot disparity map
axs[1, 0].imshow(disparity, cmap='gray')
axs[1, 0].set_title('Disparity Map')

# Plot depth map
im = axs[1, 1].imshow(depth_map, cmap='gray')
axs[1, 1].set_title('Depth Map')
plt.colorbar(im, ax=axs[1, 1], fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python-headless) (1.25.2)
# <ipython-input-1-a7a4223666d0>:22: RuntimeWarning: divide by zero encountered in divide
#   depth_map = baseline * focal_length / disparity
